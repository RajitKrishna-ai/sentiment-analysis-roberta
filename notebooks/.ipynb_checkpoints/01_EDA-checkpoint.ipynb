# %%
# -----------------------------
# EDA Notebook - SentimentSense
# Author: Rajit R Krishna
# -----------------------------

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from collections import Counter
import re

# Optional for n-grams
from sklearn.feature_extraction.text import CountVectorizer

# Set global plot style
sns.set_style("whitegrid")
# %matplotlib inline

# %%
# Load synthetic UAE dataset
data_path = "../data/synthetic_uae_reviews.csv"
df = pd.read_csv(data_path)

# Preview dataset
df.head()
# Out:
#                               review_id  \
# 0  2ac5f7d8-5aee-4427-94da-8ee8468607fc
# 1  9443d1ce-c730-4ecc-a140-eb114155ea59
# 2  a36a41b5-d239-4629-9427-7edd4447eac5
# 3  69955dd1-c69a-45ae-8e4e-0d5b209f5c45
# 4  c0e45bdf-d637-48d5-9421-c814e9495180
#
#                                          review_text product_category  rating  \
# 0       I bought this for fashion. highly recommend.          Fashion       4
# 1                I bought this for fashion. perfect.          Fashion       5
# 2  Bought this for for electronics. very happy. B...      Electronics       4
# 3                I bought this for grocery. average.          Grocery       3
# 4       Bought this for for home. very disappointed.             Home       2
#
#   sentiment  length_chars  length_tokens review_source  contains_slang  \
# 0  positive            44              7   Android App           False
# 1  positive            35              6           Web           False
# 2  positive            86             15       iOS App           False
# 3   neutral            35              6       iOS App           False
# 4  negative            44              7           Web           False
#
#            review_date            city
# 0  2025-08-04 05:24:07  Ras Al Khaimah
# 1  2024-12-15 07:12:19         Sharjah
# 2  2025-05-25 20:06:05  Ras Al Khaimah
# 3  2025-10-28 06:40:32           Ajman
# 4  2025-04-13 00:56:26           Dubai

# %%
# Basic info
df.info()

# Statistical summary
df.describe(include='all')

# Check class distribution
df['sentiment'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   review_id         5000 non-null   object
#  1   review_text       5000 non-null   object
#  2   product_category  5000 non-null   object
#  3   rating            5000 non-null   int64
#  4   sentiment         5000 non-null   object
#  5   length_chars      5000 non-null   int64
#  6   length_tokens     5000 non-null   int64
#  7   review_source     5000 non-null   object
#  8   contains_slang    5000 non-null   bool
#  9   review_date       5000 non-null   object
#  10  city              5000 non-null   object
# dtypes: bool(1), int64(3), object(7)
# memory usage: 395.6+ KB
# positive    3494
# neutral      987
# negative     519
# Name: sentiment, dtype: int64

# %%
# Review length distribution (characters)
plt.figure(figsize=(8,5))
sns.histplot(df['length_chars'], bins=50, kde=True, color='teal')
plt.title("Review Length Distribution (Characters)")
plt.xlabel("Number of Characters")
plt.ylabel("Frequency")
plt.show()

# Review length distribution (tokens)
plt.figure(figsize=(8,5))
sns.histplot(df['length_tokens'], bins=50, kde=True, color='orange')
plt.title("Review Length Distribution (Tokens)")
plt.xlabel("Number of Words")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='sentiment', data=df, palette='pastel')
plt.title("Sentiment Distribution")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='product_category', hue='sentiment', data=df, palette='Set2')
plt.title("Sentiment Distribution by Product Category")
plt.xticks(rotation=45)
plt.show()

# %%
# Function to plot wordcloud
def plot_wordcloud(text, title=None):
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
    plt.figure(figsize=(10,5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    if title:
        plt.title(title, fontsize=16)
    plt.show()

# Positive reviews
positive_text = " ".join(df[df['sentiment']=='positive']['review_text'])
plot_wordcloud(positive_text, "Positive Reviews WordCloud")

# Negative reviews
negative_text = " ".join(df[df['sentiment']=='negative']['review_text'])
plot_wordcloud(negative_text, "Negative Reviews WordCloud")

# Neutral reviews
neutral_text = " ".join(df[df['sentiment']=='neutral']['review_text'])
plot_wordcloud(neutral_text, "Neutral Reviews WordCloud")

# %%
# Function to get top n n-grams
def get_top_ngrams(corpus, ngram_range=(1,1), top_n=20):
    vec = CountVectorizer(ngram_range=ngram_range, stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:top_n]

# Example: top 20 unigrams
top_unigrams = get_top_ngrams(df['review_text'], ngram_range=(1,1))
print("Top 20 Unigrams:", top_unigrams)

# Top bigrams
top_bigrams = get_top_ngrams(df['review_text'], ngram_range=(2,2))
print("Top 20 Bigrams:", top_bigrams)

# Top trigrams
top_trigrams = get_top_ngrams(df['review_text'], ngram_range=(3,3))
print("Top 20 Trigrams:", top_trigrams)
# Out:
# Top 20 Unigrams: [('bought', 5000), ('toys', 756), ('fashion', 733), ('beauty', 722), ('grocery', 707), ('home', 704), ('electronics', 695), ('sports', 683), ('battery', 593), ('life', 593), ('good', 593), ('charges', 593), ('fast', 593), ('buy', 520), ('highly', 457), ('recommend', 457), ('works', 450), ('great', 450), ('loved', 445), ('perfect', 441)]
# Top 20 Bigrams: [('bought toys', 756), ('bought fashion', 733), ('bought beauty', 722), ('bought grocery', 707), ('bought home', 704), ('bought electronics', 695), ('bought sports', 683), ('battery life', 593), ('life good', 593), ('good charges', 593), ('charges fast', 593), ('highly recommend', 457), ('works great', 450), ('exceeded expectations', 417), ('decent price', 192), ('toys buy', 89), ('toys highly', 84), ('waste money', 81), ('size runs', 77), ('runs small', 77)]
# Top 20 Trigrams: [('battery life good', 593), ('life good charges', 593), ('good charges fast', 593), ('bought toys buy', 89), ('bought toys highly', 84), ('toys highly recommend', 84), ('size runs small', 77), ('runs small fabric', 77), ('small fabric feels', 77), ('fabric feels cheap', 77), ('bought beauty stars', 75), ('bought beauty buy', 75), ('bought sports buy', 74), ('bought electronics buy', 74), ('bought grocery loved', 74), ('bought home stars', 74), ('bought toys loved', 74), ('bought fashion perfect', 73), ('bought sports perfect', 72), ('bought home works', 72)]

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='sentiment', y='rating', data=df, palette='pastel')
plt.title("Rating vs Sentiment")
plt.show()

# %%
# Optional tosave summary statistics
eda_summary_path = "../data/eda_summary.csv"
df.describe(include='all').to_csv(eda_summary_path)
print(f"EDA summary saved to {eda_summary_path}")
